# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import sys
from matplotlib import rc

# %%
def julia(z, c, n):
    ret = np.zeros(z.shape)
    for i in range(n):
        z = z ** 2 + c
        ret[(ret == 0) & (2 < np.abs(z))] = i+1
    return ret

# %%
x_ticks = np.arange(-2,2,0.01)
y_ticks = np.arange(-2,2,0.01)
X, Y = np.meshgrid(x_ticks,y_ticks)
julia_result = julia(X + 1j * Y, 0.7 + .3j, 50)
plt.figure(figsize=(7.5,7.5))
plt.imshow(julia_result)
plt.colorbar()
print(np.max(julia_result))
plt.figure()
plt.hist(julia_result.flat);
#plt.imshow(Y)
# Out:
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in square
#   after removing the cwd from sys.path.
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in square
#   after removing the cwd from sys.path.
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in absolute
#   """
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# 16.0

# %%
x_path = np.arange(0,2*np.pi,0.005*np.pi)
c_path = .7885*np.cos(x_path) + 1j * .7885*np.sin(0 * np.pi + x_path)
plt.plot(c_path.real, c_path.imag, '.-')

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig, ax = plt.subplots(figsize=(7.5,7.5))

ax.set_xlim((-2, 2))
ax.set_ylim((-2, 2))

line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    global i
    i = 0
    #line.set_data([], [])
    return (line,)

# animation function. This is called sequentially
def animate(c):
    global i
    julia_result = julia(X + 1j * Y, c, 25)
    ax.clear()
    ax.imshow(julia_result, interpolation='bilinear', vmin=0, vmax=25)
    #plt.colorbar()
    sys.stdout.write('.' if i * 10 // len(c_path) <= (i+1) * 10 // len(c_path) else '{}%\n'.format((i * 10 // len(c_path)) * 10))
    sys.stdout.flush()
    i += 1
    return (line,)

# call the animator. blit=True means only re-draw the parts that 
# have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=c_path, interval=20, blit=True)

# %%
anim.save('julia.gif', writer='imagemagick', fps=20)

# %%
mywriter = animation.FFMpegWriter(fps=30, bitrate=7500)
anim.save('julia.mp4', writer=mywriter)
# Out:
# .
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in square
#   after removing the cwd from sys.path.
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in square
#   after removing the cwd from sys.path.
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in absolute
#   """
# E:\programs\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in greater
#   """
# ...............................................................................................................................................................................................................................................................................................................................................................................................................
